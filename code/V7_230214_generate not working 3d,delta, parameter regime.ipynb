# %%
from datetime import date
from qutip import *
from numpy import *
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import animation

# %%
def plot_wigner(rho, fig=None, ax=None):
    if fig is None or ax is None:
        fig, ax=plt.subplots(1,1,figsize=(8,8))
    if isket(rho):
        rho=ket2dm(rho)
    xvec=linspace(-7.5, 7.5, 200)
    W=wigner(rho,xvec,xvec)
    wlim=abs(W).max()
    ax.contourf(xvec, xvec, W, 100, norm=mpl.colors.Normalize(-wlim,wlim), cmap=mpl.cm.get_cmap('RdBu'))
    ax.set_xlabel(r'x1', fontsize=16)
    ax.set_ylabel(r'x2', fontsize=16)
    return fig, ax

# %%
class system:
    def __init__(self, chi, tau_speed, ramp, catsize, start, stop, num):
        self.purechi=chi
        self.chi=chi*(2)*pi
        self.ramp=ramp
        self.catsize=catsize
        self.tau_speed=tau_speed
        self.tau=self.tau_speed/self.chi #puri=5, frattini=2.14
        self.start=start
        self.stop=stop
        self.num=num
        self.tlist=linspace(self.start, self.stop, self.num)
        self.N=15
        self.x_chi=[]
        self.y_v=[]
        self.fidelity=[]
        self.a=destroy(self.N)
        self.ad=self.a.dag()
        self.H0=self.ad*self.ad*self.a*self.a
        self.Hdet=self.ad*self.a
        self.Hx=self.ad*self.ad+self.a*self.a
        self.Hy=self.ad*self.ad-self.a*self.a
        self.zero=basis(self.N, 0)
        self.one=basis(self.N, 1)
        self.N_plus=(1/(sqrt(2*(1+(exp((-2)*self.catsize))))))
        self.zero=coherent(self.N, 0)
        self.P0=self.catsize*self.chi
        self.expectedcat=self.N_plus*(coherent(self.N, sqrt(self.catsize))+coherent(self.N, -sqrt(self.catsize)))
    def Epx(self, t, args):
        if self.ramp == 'exp':
            return self.P0 *(1-exp((-(t)**4)/(self.tau**4)))
        elif self.ramp == 'tanh':
            return self.P0*tanh(4*(t/self.tau))
        elif self.ramp == 'lin':
            if t<self.tau:
                return self.P0*(t/self.tau) 
            if t>=self.tau :
                return self.P0
        elif self.ramp =='inst':
            return self.P0   
    def det(self, t, args):
        return (-1.7)*(self.chi)*(1-(t/self.tau))     
    def Epy(self, t,args):
        Ep= self.P0*self.chi*(1-exp((-(t)**4)/(self.tau**4)))
        alpha_0=sqrt(Ep/self.chi)
        alpha_prime=sqrt(0.5*(1/sqrt(self.catsize*(1-exp((-(t)**4)/(self.tau**4)))))*((-1)*self.catsize*exp((-(t)**4)/(self.tau**4)))*((-4)*(t**3)/(self.tau**4)))
        N_m=1/(sqrt(2*(1-exp((-2)*(self.catsize)))))
        return (1j*alpha_prime)/((1+2*alpha_0)*(N_m))
    def init_fidelity_det(self, spec,kstart, kstop, knum, vstart, vstop, vnum): 
        kerr=linspace(kstart, kstop, knum)
        tau_speed=linspace(vstart,vstop, vnum)
        x=[]
        y=[]
        fid=[]
        t=[]
        for chi in kerr:
            for v in tau_speed:
                    def detuning(t, args):
                        return (-1.7)*(2*pi*chi)*(1-(t/(v/(2*pi*chi))))
                    def Epx_k_v(t, args):
                        if t<(v/(2*pi*chi)):
                            return self.catsize*2*pi*chi*(t/(v/(2*pi*chi))) 
                        if t>=(v/(2*pi*chi)) :
                            return self.catsize*2*pi*chi
                    result=mesolve([(-1)*(2*pi)*chi*self.H0,[self.Hx, Epx_k_v],[self.Hdet, detuning]],self.zero, self.tlist, [], [])
                    f=[]
                    for i in range(len(self.tlist)):
                        f.append(fidelity(self.expectedcat, result.states[i]))
                    maxfid=max(f)
                    self.x_chi.append(chi)
                    self.y_v.append(v)
                    self.fidelity.append(round(maxfid*100,2))
                    if maxfid<0.9:
                        pass
                    if maxfid>=0.9:
                        x.append(chi)
                        y.append(v)
                        fid.append(round(maxfid*100,2))
                        t.append(round(((self.stop-self.start)/self.num)*(f.index(maxfid)+1),2))
                    f.clear()
            fig=plt.figure(figsize=(8,8))
        norm=mpl.colors.Normalize(vmin=90, vmax=100)
        ax=fig.add_subplot(111,projection='3d')
        ax.scatter(x,y,t, c=fid,marker='o', s=15, cmap='viridis')
        ax.set_xlabel('kerr(MHz)')
        ax.set_ylabel('ramp speed')
        ax.set_zlabel('taken_time')
        fig.colorbar(plt.cm.ScalarMappable(norm=norm,cmap='viridis'),ax=ax, shrink=0.5)
        name=f"{spec},n={self.catsize},k=({kstart},{kstop},{knum}),v=({vstart},{vstop},{vnum})"
        file_name=f"C:/Users/kimje/Desktop/Project/Posco/Cat/data/fidelity/230217/{name}.png"
        plt.savefig(file_name, format='png', dpi=100, bbox_inches='tight')
        plt.show()
    def init_fidelity_3d(self, spec, kstart, kstop, knum, vstart, vstop, vnum): 
        kerr=linspace(kstart, kstop, knum)
        tau_speed=linspace(vstart,vstop, vnum) # adiabatic cond tau>>1/(Delta_gap=4Kn) =>min v=0.1!(JW setting)
        x=[]
        y=[]
        fid=[]
        t=[]
        for chi in kerr:
            for v in tau_speed:
                def Epx_k_v(t, args):
                    return (2*pi)*chi*self.catsize*(1-exp((-(t)**4)/((v/(2*pi)*chi)**4)))
                result=mesolve([(-1)*(2*pi)*chi*self.H0,[self.Hx, Epx_k_v]],self.zero, self.tlist, [], [])
                              
                f=[]
                for i in range(len(self.tlist)):
                    f.append(fidelity(self.expectedcat, result.states[i]))
                maxfid=max(f)
                self.x_chi.append(chi)
                self.y_v.append(v)
                self.fidelity.append(round(maxfid*100,2))
                if maxfid<0.9:
                    pass
                if maxfid>=0.9:
                    x.append(chi)
                    y.append(v)
                    fid.append(round(maxfid*100,2))
                    t.append(round(((self.stop-self.start)/self.num)*(f.index(maxfid)+1),2))
                f.clear()
        fig=plt.figure(figsize=(8,8))
        norm=mpl.colors.Normalize(vmin=90, vmax=100)
        ax=fig.add_subplot(111,projection='3d')
        ax.scatter(x,y,t, c=fid,marker='o', s=15, cmap='viridis')
        ax.set_xlabel('kerr(MHz)')
        ax.set_ylabel('ramp speed')
        ax.set_zlabel('taken_time')
        fig.colorbar(plt.cm.ScalarMappable(norm=norm,cmap='viridis'),ax=ax, shrink=0.5)
        name=f"{spec},n={self.catsize},k=({kstart},{kstop},{knum}),v=({vstart},{vstop},{vnum})"
        file_name=f"C:/Users/kimje/Desktop/Project/Posco/Cat/data/fidelity/230217/{name}.png"
        plt.savefig(file_name, format='png', dpi=100, bbox_inches='tight')
        plt.show()
    
        
    def generate(self, H, spec, speed):
        n=len(self.tlist)
        if H=='x':
            H=[(-1)*self.chi*self.H0,[self.Hx, self.Epx]]
        elif H=='x,y':
            H=[(-1)*self.chi*self.H0,[self.Hx, self.Epx],[self.Hy, self.Epy]]
        elif H=='x,det':
            H=[(-1)*self.chi*self.H0,[self.Hx, self.Epx],[self.Hdet, self.det]]
        result=mesolve(H, self.zero, self.tlist, [], [])        
        # fidelity, time
        f=[]
        for i in range(n):
            f.append(fidelity(self.expectedcat, result.states[i]))
        maxfid=max(f)
        maxfid_idx=f.index(maxfid)
        time_taken=((self.stop-self.start)/self.num)*(maxfid_idx+1)
        # animation
        fig, ax= plt.subplots(1,1,figsize=(8,8))
        def update(frame):
            plot_wigner(result.states[frame*speed], fig=fig, ax=ax)
        ani=animation.FuncAnimation(fig, update, frames=int(n/speed))
        FFwriter=animation.FFMpegWriter()
        name=f"n={spec},({self.purechi},{self.tau_speed},{self.catsize}),F,t=({round(maxfid*100,2)},{round(time_taken,2)}us),({self.ramp},{H}),t=({self.start},{self.stop},{self.num}).mp4"
        file_name=f"C:/Users/kimje/Desktop/Project/Posco/Cat/animation/230217/{name}.mp4"
        ani.save(file_name, writer=FFwriter)
        plt.close()
        return maxfid, time_taken

# %%
sys=system(chi=0.75, tau_speed=5, ramp='exp', catsize=4, start=0, stop=2,num=500)

# %%
sys.generate(H='x,det',spec='test',speed=20)

# %%
sys.init_fidelity_det('ref',
kstart=0.75, kstop=40, knum=3,
vstart=0.1, vstop=20, vnum=3)
# Out:
# c:\Users\kimje\anaconda3\envs\qutip\lib\site-packages\scipy\integrate\_ode.py:1013: UserWarning: zvode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\kimje\Desktop\Project\Posco\Cat\code\V7_230214_3d,delta, parameter regime.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> sys.init_fidelity_det('ref',
#       <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> kstart=0.75, kstop=40, knum=3,
#       <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> vstart=0.1, vstop=20, vnum=3)
#
# c:\Users\kimje\Desktop\Project\Posco\Cat\code\V7_230214_3d,delta, parameter regime.ipynb Cell 5 in system.init_fidelity_det(self, spec, kstart, kstop, knum, vstart, vstop, vnum)
#      <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=62'>63</a>     if t>=(v/(2*pi*chi)) :
#      <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=63'>64</a>         return self.catsize*2*pi*chi
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=64'>65</a> result=mesolve([(-1)*(2*pi)*chi*self.H0,[self.Hx, Epx_k_v],[self.Hdet, detuning]],self.zero, self.tlist, [], [])
#      <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=65'>66</a> f=[]
#      <a href='vscode-notebook-cell:/c%3A/Users/kimje/Desktop/Project/Posco/Cat/code/V7_230214_3d%2Cdelta%2C%20parameter%20regime.ipynb#W4sZmlsZQ%3D%3D?line=66'>67</a> for i in range(len(self.tlist)):
#
# File c:\Users\kimje\anaconda3\envs\qutip\lib\site-packages\qutip\mesolve.py:217, in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar, _safe_mode)
#     205 use_mesolve = ((c_ops and len(c_ops) > 0)
#     206                or (not isket(rho0))
#     207                or (isinstance(H, Qobj) and issuper(H))
#    (...)
#     213                or (not isinstance(H, (Qobj, QobjEvo)) and callable(H) and
#     214                         options.rhs_with_state))
#     216 if not use_mesolve:
# --> 217     return sesolve(H, rho0, tlist, e_ops=e_ops, args=args, options=options,
#     218                    progress_bar=progress_bar, _safe_mode=_safe_mode)
#     220 if isket(rho0):
#     221     rho0 = ket2dm(rho0)
#
# File c:\Users\kimje\anaconda3\envs\qutip\lib\site-packages\qutip\sesolve.py:136, in sesolve(H, psi0, tlist, e_ops, args, options, progress_bar, _safe_mode)
#     133     v = psi0.full().ravel('F')
#     134     func(0., v, *ode_args) + v
# --> 136 res = _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, options,
#     137                          progress_bar, dims=psi0.dims)
#     138 if e_ops_dict:
#     139     res.expect = {e: res.expect[n]
#     140                   for n, e in enumerate(e_ops_dict.keys())}
#
# File c:\Users\kimje\anaconda3\envs\qutip\lib\site-packages\qutip\sesolve.py:329, in _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, opt, progress_bar, dims)
#     327 progress_bar.update(t_idx)
#     328 if not r.successful():
# --> 329     raise Exception("ODE integration error: Try to increase "
#     330                     "the allowed number of substeps by increasing "
#     331                     "the nsteps parameter in the Options class.")
#     332 # get the current state / oper data if needed
#     333 if opt.store_states or opt.normalize_output \
#     334    or n_expt_op > 0 or expt_callback:
#
# Exception: ODE integration error: Try to increase the allowed number of substeps by increasing the nsteps parameter in the Options class.

# %%
sys.generate(H=)

# %%
sys.init_fidelity('ref',type='3ref',
kstart=0.75, kstop=40, knum=50,
vstart=0.1, vstop=20, vnum=30)

# %%
sys.init_fidelity('ref',type='3ref',
kstart=0.75, kstop=40, knum=50,
vstart=0.1, vstop=20, vnum=30)

# %%
x=[1,2,3]
y=[2,3,4]
z=[1,3,5]
color=[3,4,50]
fig=plt.figure(figsize=(10,10))
norm=mpl.colors.Normalize(vmin=-1, vmax=1)
ax=fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z,c=color,marker='o', s=15, cmap='viridis')
fig.colorbar(plt.cm.ScalarMappable(norm=norm,cmap='viridis'),ax=ax, shrink=0.5)
plt.savefig('x')
